# %% [markdown]
# # Phase 3: Order Execution & Portfolio Management
#
# This notebook demonstrates how to place, modify, and cancel orders, and how to verify margins and existing positions.

# %%
# 1. Setup & Imports
import sys
import os
sys.path.append(os.path.abspath('../'))

print("Order execution module loaded")

# %%
# 2. View Margin / Funds Available
# margin = groww.get_margin()
print("Checking account balance/margins...")

# %%
# 3. Place Order (Cash Equity / F&O)
# Example order payload:
# order = groww.place_order(
#     symbol="SBIN",
#     exchange="NSE",
#     transaction_type="BUY",
#     order_type="LIMIT",
#     quantity=1,
#     price=800.00
# )
print("Mock/Demo order placement cell")
