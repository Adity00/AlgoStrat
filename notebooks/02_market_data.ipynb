# %% [markdown]
# # Phase 2: Groww Market Data Fetching
#
# This notebook demonstrates how to query instrument lists, historical data, and handle live feed subscription.

# %%
# 1. Import dependencies and initialize client
import sys
import os
sys.path.append(os.path.abspath('../'))

from dotenv import load_dotenv
from growwapi import GrowwAPI
import pandas as pd

load_dotenv()
api_key = os.getenv("GROWW_API_KEY")
secret = os.getenv("GROWW_API_SECRET")

# Placeholder/Mock initialization. Replace with active tokens once authenticated.
print("Ready for market data testing")

# %%
# 2. Fetch Instruments
# Replace with SDK-specific instruments query
print("Fetching active instruments / symbols...")

# %%
# 3. Fetch Historical Candles
# Example structure:
# candles = groww.get_historical_data(symbol="SBIN", interval="1d", from_date="2026-01-01", to_date="2026-06-01")
print("Historical data query demo")
